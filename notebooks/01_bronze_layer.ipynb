# %%
import pandas as pd
import os

# %%
BASE_PATH = "E:/C-DAC/Major Project/AI-Based-Maritime-Port-Intelligence"

RAW_PATH = os.path.join(BASE_PATH, "data", "raw")
BRONZE_PATH = os.path.join(BASE_PATH, "data", "bronze")

# %% [markdown]
# ## Bronze Layer

# %%
df1 = pd.read_csv(os.path.join(RAW_PATH, "df1_ais_kattegat.csv"))
df2 = pd.read_csv(os.path.join(RAW_PATH, "df2_ais_global.csv"))
df3 = pd.read_csv(os.path.join(RAW_PATH, "df3_ais_unacorn.csv"))
df4 = pd.read_csv(os.path.join(RAW_PATH, "df4_container_tracking.csv"),low_memory=False)

# %%
df1.to_csv(os.path.join(BRONZE_PATH, "ais_kattegat.csv"), index=False)
df2.to_csv(os.path.join(BRONZE_PATH, "ais_global.csv"), index=False)
df3.to_csv(os.path.join(BRONZE_PATH, "ais_unacorn.csv"), index=False)
df4.to_csv(os.path.join(BRONZE_PATH, "container_tracking.csv"), index=False)

# %%
print("df1 rows:", df1.shape)
print("df2 rows:", df2.shape)
print("df3 rows:", df3.shape)
print("df4 rows:", df4.shape)
# Out:
# df1 rows: (358351, 10)
# df2 rows: (7167046, 17)
# df3 rows: (103997, 17)
# df4 rows: (823672, 17)
